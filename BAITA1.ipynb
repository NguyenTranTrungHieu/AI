# %%
import pandas as pd
import numpy as np
time_index = pd.date_range('01/01/2023',periods = 100000, freq = '30s')
dataframe=pd.DataFrame(index=time_index)
dataframe['Acess_Amount'] = np.random.randint(1,10,100000)
dataframe.resample('W').sum()
# Out:
#             Acess_Amount
# 2023-01-01         14371
# 2023-01-08        101001
# 2023-01-15        100780
# 2023-01-22        100753
# 2023-01-29        101476
# 2023-02-05         82510

# %%
#tìm số huy chương của quốc gia 
import pandas as pd
url = 'http://winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data
# Out:
#       Year      City       Sport      Discipline  NOC            Event  \
# 0     1924  Chamonix     Skating  Figure skating  AUT       individual
# 1     1924  Chamonix     Skating  Figure skating  AUT       individual
# 2     1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3     1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# ...    ...       ...         ...             ...  ...              ...
# 2306  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2307  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2308  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2309  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
# 2310  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# 2               X    Gold
# ...

# %%
print('So huy chuong vang dat duoc: ',data[(data['NOC']=='USA')&(data['Medal']=='Gold')].count())
# Out:
# So huy chuong vang dat duoc:  Year            78
# City            78
# Sport           78
# Discipline      78
# NOC             78
# Event           78
# Event gender    78
# Medal           78
# dtype: int64

# %%
data=data.set_index(data['NOC'])
data.loc['AUT']
# Out:
#      Year        City    Sport       Discipline  NOC                  Event  \
# NOC
# AUT  1924    Chamonix  Skating   Figure skating  AUT             individual
# AUT  1924    Chamonix  Skating   Figure skating  AUT             individual
# AUT  1924    Chamonix  Skating   Figure skating  AUT                  pairs
# AUT  1928  St. Moritz  Skating   Figure skating  AUT             individual
# AUT  1928  St. Moritz  Skating   Figure skating  AUT             individual
# ..    ...         ...      ...              ...  ...                    ...
# AUT  2006       Turin   Skiing  Nordic Combined  AUT                   Team
# AUT  2006       Turin   Skiing      Ski Jumping  AUT  K120 individual (90m)
# AUT  2006       Turin   Skiing      Ski Jumping  AUT  K120 individual (90m)
# AUT  2006       Turin   Skiing      Ski Jumping  AUT        K120 team (90m)
# AUT  2006       Turin   Skiing        Snowboard  AUT  Giant parallel slalom
#
#     Event gender   Medal
# NOC
# ...

# %%
ata=data.set_index(data['NOC'])
data.loc['AUT']
print('So huy chuong Ao đat đuoc: ',data[(data['NOC']=='USA')&(data['Medal'])].count())
# Out:
# So huy chuong Ao đat đuoc:  Year            216
# City            216
# Sport           216
# Discipline      216
# NOC             216
# Event           216
# Event gender    216
# Medal           216
# dtype: int64
